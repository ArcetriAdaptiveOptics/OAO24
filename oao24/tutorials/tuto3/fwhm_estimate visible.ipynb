# %%
# !pip uninstall -y oao24
# !pip install git+https://github.com/ArcetriAdaptiveOptics/OAO24.git
# Out:
# Found existing installation: oao24 0.1
# Uninstalling oao24-0.1:
#   Successfully uninstalled oao24-0.1
# Collecting git+https://github.com/ArcetriAdaptiveOptics/OAO24.git
#   Cloning https://github.com/ArcetriAdaptiveOptics/OAO24.git to /private/var/folders/yy/y6mh4b390sj24kqkcp9nl2c40000gp/T/pip-req-build-9v42r70d
#   Running command git clone --filter=blob:none --quiet https://github.com/ArcetriAdaptiveOptics/OAO24.git /private/var/folders/yy/y6mh4b390sj24kqkcp9nl2c40000gp/T/pip-req-build-9v42r70d
#   Resolved https://github.com/ArcetriAdaptiveOptics/OAO24.git to commit 277bd41169d983cad20c44ed55f3c8aa1d975165
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /Users/lbusoni/opt/anaconda3/envs/oao24/lib/python3.12/site-packages (from oao24==0.1) (1.26.4)
# Requirement already satisfied: astropy in /Users/lbusoni/opt/anaconda3/envs/oao24/lib/python3.12/site-packages (from oao24==0.1) (6.1.3)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /Users/lbusoni/opt/anaconda3/envs/oao24/lib/python3.12/site-packages (from astropy->oao24==0.1) (2.0.1.4)
# Requirement already satisfied: astropy-iers-data>=0.2024.7.29.0.32.7 in /Users/lbusoni/opt/anaconda3/envs/oao24/lib/python3.12/site-packages (from astropy->oao24==0.1) (0.2024.9.2.0.33.23)
# Requirement already satisfied: PyYAML>=3.13 in /Users/lbusoni/opt/anaconda3/envs/oao24/lib/python3.12/site-packages (from astropy->oao24==0.1) (6.0.1)
# Requirement already satisfied: packaging>=19.0 in /Users/lbusoni/opt/anaconda3/envs/oao24/lib/python3.12/site-packages (from astropy->oao24==0.1) (24.1)
# Building wheels for collected packages: oao24
#   Building wheel for oao24 (setup.py) ... done
#   Created wheel for oao24: filename=oao24-0.1-py3-none-any.whl size=13722898 sha256=67882b1dd00fe38099b7ca3d7d1edaaf6dd4fa713200a219b47cced2bae1f13b
#   Stored in directory: /private/var/folders/yy/y6mh4b390sj24kqkcp9nl2c40000gp/T/pip-ephem-wheel-cache-p01to2nw/wheels/7a/76/63/a40f38a93ba61eeeed0e55302f7271eed0e932d99461d44bf8
# Successfully built oao24
# Installing collected packages: oao24
# Successfully installed oao24-0.1

# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.modeling import models, fitting
from oao24.package_data import InfraredExampleData, VisibleExampleData
from oao24 import image_processing

# %%
#background_image = InfraredExampleData.get_camera_dark_data()
#cl_raw_image_cube = InfraredExampleData.get_close_loop_data_cube()
background_image = VisibleExampleData.get_camera_dark_data()
cl_raw_image_cube = VisibleExampleData.get_close_loop_data_cube()
    
ao_image = image_processing.make_master_image(cl_raw_image_cube, background_image)
# Out:
# Background : ROIs mean values 111.447 111.795 111.132 111.2 - Average 111.394 ADU
# Raw image #0 : ROIs mean values 174.358 136.18 125.416 120.257 - Average 139.053 ADU
# Master image : ROIs mean values 3206.59 1148.26 625.379 419.426 - Average 1349.91 ADU
# /Users/lbusoni/opt/anaconda3/envs/oao24/lib/python3.12/site-packages/oao24/image_processing.py:71: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(arr-np.median(arr)+1), cmap='inferno')
# /Users/lbusoni/opt/anaconda3/envs/oao24/lib/python3.12/site-packages/oao24/image_processing.py:71: RuntimeWarning: invalid value encountered in log10
#   plt.imshow(np.log10(arr-np.median(arr)+1), cmap='inferno')

# %% [markdown]
# ## Science camera constants

# %%
RAD2ARCSEC=180/np.pi*3600
pupil_diameter = 1.52 
wavelength = 800e-9 
# Plate scale is typically saved in the FITS image header
# or it can be calibrated using 2 sources of known distance
# Here we use the Papyrus nominal optical design values
# F/# = 23
# The DL PSF size in m on the focal is F/H * wavelength
orca_pixel_in_meter = 6.5e-6
f_number =  23
telescope_focal_length = f_number * pupil_diameter
# so the size of the pixel in arcsec is 
pixel_scale_in_arcsec =orca_pixel_in_meter / telescope_focal_length * RAD2ARCSEC 

# the DL size (=lambda/D) in units of arcsec or pixels are therefore
dl_size_in_arcsec = wavelength / pupil_diameter * RAD2ARCSEC 
dl_size_in_pixels = dl_size_in_arcsec / pixel_scale_in_arcsec

print("ORCA pixel scale: %g arcsec/pixel" % pixel_scale_in_arcsec)
print("DL PSF size: %g arcsec" % dl_size_in_arcsec)
print("DL PSF size: %g pixels" % dl_size_in_pixels)


# We work on a roi of the science image with the star image centered in the field
star_roi = ao_image[80:130, 90:140]
#star_roi = ao_image[200:400, 250:450] # good for IR open loop
# star_roi = ao_image # good for Vis open loop
# Out:
# ORCA pixel scale: 0.0383501 arcsec/pixel
# DL PSF size: 0.0949904 arcsec
# DL PSF size: 2.47692 pixels

# %% [markdown]
# We start simple with a Gaussian fit
# Note that the actual PSF is quite similar to a Airy function, as the AO correction is high
# Check PSF fitting residual (PSF-GaussianFit)

# %%
  
amp = star_roi.max()
x0 = np.where(star_roi == star_roi.max())[1][0]
y0 = np.where(star_roi == star_roi.max())[0][0]
sigma_x = 2.5/(2*np.sqrt(2*np.log(2)))
sigma_y = sigma_x

model_gauss = models.Gaussian2D(amp, x0, y0, sigma_x, sigma_y)

fitter = fitting.LevMarLSQFitter()

roi_shape = star_roi.shape
y, x = np.mgrid[:roi_shape[0], :roi_shape[1]]

best_fit_gauss = fitter(model_gauss, x, y, z = star_roi)
psf_residual_gauss= best_fit_gauss(x,y)-star_roi
plt.figure()
plt.imshow(star_roi)
plt.colorbar()
plt.title('PSF')

plt.figure()
plt.imshow(psf_residual_gauss)
plt.colorbar()
plt.title('PSF fitting residual (PSF-Gaussian fit)')

plt.figure()
plt.plot(best_fit_gauss(x,y)[29,15:45], label='Gaussian fit')
plt.plot(star_roi[29,15:45], label='PSF')
plt.plot(psf_residual_gauss[29,15:45], label='PSF fitting residual')
plt.legend()

# %% [markdown]
# Repeat with a Moffat2D model
# It is capable of better fitting the PSF wing
# Moffat is typically used to fit Seeing limited PSF

# %%
 
    
    
model_moffat = models.Moffat2D(amp, x0, y0, 3.6)
best_fit_moffat = fitter(model_moffat, x, y, z = star_roi)
psf_residual_moffat= best_fit_moffat(x,y)-star_roi
plt.figure()
plt.imshow(star_roi)
plt.colorbar()
plt.title('PSF')

plt.figure()
plt.imshow(psf_residual_moffat)
plt.colorbar()
plt.title('PSF fitting residual (PSF-Moffat fit)')

plt.figure()
plt.plot(best_fit_moffat(x,y)[29,15:45], label='Moffat fit')
plt.plot(star_roi[29,15:45], label='PSF')
plt.plot(psf_residual_moffat[29,15:45], label='PSF Moffat fitting residual')
plt.legend()

# %% [markdown]
# Compare Gaussian and Moffat

# %%
plt.figure()
plt.plot(best_fit_gauss(x,y)[29,15:45], label='Gaussian fit')
plt.plot(best_fit_moffat(x,y)[29,15:45], label='Moffat fit')
plt.plot(star_roi[29,15:45], label='PSF')
plt.plot(psf_residual_gauss[29,15:45], label='PSF Gaussian fitting residual')
plt.plot(psf_residual_moffat[29,15:45], label='PSF Moffat fitting residual')
plt.legend()

# %%
###
# convert sigma to FWHM!
# average major and minor axis of the Gaussian
# convert from px to arcsec using the plate scale (given or calibrated)
#
# Advanced: PSF ellipticity can tell you something about anisoplanatism, residual astigmatism, wind direction, ...
###

fwhm_gaussian_fit_px = np.mean(best_fit_gauss.parameters[3:5]*(2*np.sqrt(2*np.log(2))))
fwhm_gaussian_fit_arcsec = fwhm_gaussian_fit_px * pixel_scale_in_arcsec
print('FWHM from Gaussian fit %g arcsec' % (fwhm_gaussian_fit_arcsec))

###
# compute FWHM for the Moffat
# convert from px to arcsec using the plate scale (given or calibrated)
###

fwhm_moffat_fit_px  = best_fit_moffat.parameters[3] * 2
fwhm_moffat_fit_arcsec = fwhm_moffat_fit_px * pixel_scale_in_arcsec
print('FWHM from Moffat fit %g arcsec' % fwhm_moffat_fit_arcsec)
print('DL FWHM %g arcsec' % dl_size_in_arcsec)
# Out:
# FWHM from Gaussian fit 0.19496 arcsec
# FWHM from Moffat fit 0.149647 arcsec
# DL FWHM 0.0949904 arcsec

# %% [markdown]
# ## Questions
# 1. Repeat the fit with Airy model `astropy.modeling.functional_models.AiryDisk2D`
# 2. Repeat the same analysis for the Visible image (Hint: use `VisibleExampleData.get_close_loop_data_cube()`, update wavelengths & co)
# 2. Estimate the FWHM of the seeing limited image  (NB: the open loop examples images in IR and VIS are not good enough)
